# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashr90/ADS/blob/main/Infix_to_pefix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def precedence(op):
    if op == '+' or op == '-':
        return 1
    if op == '*' or op == '/':
        return 2
    return 0

def infix_to_prefix(expression):
    def is_operator(c):
        return c in {'+', '-', '*', '/'}

    def infix_to_postfix(exp):
        stack = []
        output = []
        for char in exp:
            if char.isalnum():  # Operand
                output.append(char)
            elif char == '(':
                stack.append(char)
            elif char == ')':
                while stack and stack[-1] != '(':
                    output.append(stack.pop())
                stack.pop()  # Pop '('
            else:  # Operator
                while stack and precedence(stack[-1]) >= precedence(char):
                    output.append(stack.pop())
                stack.append(char)
        while stack:
            output.append(stack.pop())
        return ''.join(output)

    # Reverse the infix expression and replace ( with ) and vice versa
    expression = expression[::-1]
    expression = ''.join(['(' if c == ')' else ')' if c == '(' else c for c in expression])

    # Convert modified infix to postfix
    postfix = infix_to_postfix(expression)

    # Reverse postfix to get prefix
    return postfix[::-1]

# Input expression
infix_expression = "A+(B-C*D)/E"
prefix_expression = infix_to_prefix(infix_expression)
print("Prefix Expression:", prefix_expression)
# Out:
# Prefix Expression: +A/-B*CDE
